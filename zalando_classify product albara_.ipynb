# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
from keras.datasets import fashion_mnist
(X_train, y_train),(X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
kategori = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shrit', 'Sneaker', 'Bag', 'Ankle boot']

# %%
i = random.randint(1, len(X_train))
plt.figure()
plt.imshow(X_train[i,:,:], cmap='gray')
plt.title('item ke {} . kategori = {}' .format(i, kategori[y_train[i]]))
plt.show()

# %%
nrow = 10
ncol = 10
fig, axes = plt.subplots(nrow, ncol)
axes = axes.ravel()
ntraining = len(X_train)
for i in np.arange(0, nrow*ncol):
  indexku = np.random.randint(0, ntraining)
  axes[i].imshow(X_train [indexku,:,:], cmap = 'gray')
  axes[i].set_title(int(y_train[indexku]), fontsize = 8)
  axes[i].axis('off')
plt.subplots_adjust(hspace=0.4)

# %%
X_train = X_train/225
X_test = X_test/225

# %%
from sklearn.model_selection import train_test_split
X_train, X_validate, y_train, y_validate = train_test_split(X_train,y_train,test_size=0.2,random_state=123)

# %%
X_train = X_train.reshape(X_train.shape[0], *(28,28,1))
X_test = X_test.reshape(X_test.shape[0], *(28,28,1))
X_validate = X_validate.reshape(X_validate.shape[0], *(28,28,1))

# %%
from keras.models import Sequential
from keras.layers import Conv2D , MaxPooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam

# %%
classifier = Sequential()

# %%
classifier.add(Conv2D(32,(3,3), input_shape=(28, 28, 1) , activation = 'relu'))

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
classifier.add(Dropout(0.25))

# %%
classifier.add(Flatten())

# %%
classifier.add(Dense(activation='relu', units=32))

# %%
classifier.add(Dense(activation='sigmoid', units=10))

# %%
classifier.compile(loss='sparse_categorical_crossentropy',
                   optimizer=Adam(lr=0.001),
                   metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                173088
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 173,738
# Trainable params: 173,738
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model (classifier, to_file='ini_model_NN_saya.png',
            show_shapes = True,
            show_layer_names = False)

# %%
run_model = classifier.fit(X_train, y_train,
                           batch_size = 480,
                           epochs = 30,
                           verbose = 1,
                           validation_data = (X_validate, y_validate))
# Out:
# Epoch 1/30
# 100/100 [==============================] - 19s 180ms/step - loss: 1.1168 - accuracy: 0.6205 - val_loss: 0.4795 - val_accuracy: 0.8372
# Epoch 2/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.4473 - accuracy: 0.8435 - val_loss: 0.3964 - val_accuracy: 0.8658
# Epoch 3/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.3865 - accuracy: 0.8649 - val_loss: 0.3585 - val_accuracy: 0.8758
# Epoch 4/30
# 100/100 [==============================] - 17s 174ms/step - loss: 0.3577 - accuracy: 0.8755 - val_loss: 0.3404 - val_accuracy: 0.8806
# Epoch 5/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.3353 - accuracy: 0.8807 - val_loss: 0.3265 - val_accuracy: 0.8828
# Epoch 6/30
# 100/100 [==============================] - 17s 175ms/step - loss: 0.3143 - accuracy: 0.8888 - val_loss: 0.3121 - val_accuracy: 0.8896
# Epoch 7/30
# 100/100 [==============================] - 17s 174ms/step - loss: 0.3025 - accuracy: 0.8914 - val_loss: 0.3054 - val_accuracy: 0.8936
# Epoch 8/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2969 - accuracy: 0.8937 - val_loss: 0.2935 - val_accuracy: 0.8971
# Epoch 9/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2871 - accuracy: 0.8960 - val_loss: 0.2909 - val_accuracy: 0.8950
# Epoch 10/30
# 100/100 [==============================] - 17s 174ms/step - loss: 0.2776 - accuracy: 0.9037 - val_loss: 0.2863 - val_accuracy: 0.8984
# Epoch 11/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2650 - accuracy: 0.9047 - val_loss: 0.2752 - val_accuracy: 0.9026
# Epoch 12/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2564 - accuracy: 0.9092 - val_loss: 0.2754 - val_accuracy: 0.9031
# Epoch 13/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2569 - accuracy: 0.9088 - val_loss: 0.2729 - val_accuracy: 0.9055
# Epoch 14/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2484 - accuracy: 0.9109 - val_loss: 0.2663 - val_accuracy: 0.9058
# Epoch 15/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2366 - accuracy: 0.9150 - val_loss: 0.2670 - val_accuracy: 0.9044
# Epoch 16/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2339 - accuracy: 0.9153 - val_loss: 0.2605 - val_accuracy: 0.9092
# Epoch 17/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2356 - accuracy: 0.9160 - val_loss: 0.2593 - val_accuracy: 0.9085
# Epoch 18/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2290 - accuracy: 0.9157 - val_loss: 0.2544 - val_accuracy: 0.9100
# Epoch 19/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2195 - accuracy: 0.9202 - val_loss: 0.2508 - val_accuracy: 0.9124
# Epoch 20/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2166 - accuracy: 0.9228 - val_loss: 0.2507 - val_accuracy: 0.9115
# Epoch 21/30
# 100/100 [==============================] - 17s 173ms/step - loss: 0.2150 - accuracy: 0.9217 - val_loss: 0.2516 - val_accuracy: 0.9116
# Epoch 22/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2164 - accuracy: 0.9221 - val_loss: 0.2486 - val_accuracy: 0.9119
# Epoch 23/30
# 100/100 [==============================] - 17s 171ms/step - loss: 0.2045 - accuracy: 0.9277 - val_loss: 0.2502 - val_accuracy: 0.9109
# Epoch 24/30
# 100/100 [==============================] - 17s 171ms/step - loss: 0.2023 - accuracy: 0.9256 - val_loss: 0.2441 - val_accuracy: 0.9137
# Epoch 25/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2019 - accuracy: 0.9251 - val_loss: 0.2437 - val_accuracy: 0.9147
# Epoch 26/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.1914 - accuracy: 0.9316 - val_loss: 0.2502 - val_accuracy: 0.9100
# Epoch 27/30
# 100/100 [==============================] - 17s 171ms/step - loss: 0.1983 - accuracy: 0.9267 - val_loss: 0.2502 - val_accuracy: 0.9100
# Epoch 28/30
# 100/100 [==============================] - 17s 171ms/step - loss: 0.1925 - accuracy: 0.9307 - val_loss: 0.2413 - val_accuracy: 0.9153
# Epoch 29/30
# 100/100 [==============================] - 17s 171ms/step - loss: 0.1891 - accuracy: 0.9302 - val_loss: 0.2410 - val_accuracy: 0.9165
# Epoch 30/30
# 100/100 [==============================] - 17s 172ms/step - loss: 0.1851 - accuracy: 0.9333 - val_loss: 0.2457 - val_accuracy: 0.9137

# %%
print(run_model.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(run_model.history['accuracy'])
plt.plot(run_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validate'], loc='upper left')
plt.show()

# %%
plt.plot(run_model.history['loss'])
plt.plot(run_model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validate'], loc='upper left')
plt.show()

# %%
evaluasi = classifier.evaluate(X_test, y_test)
print('test sccuracy ={:.2f}%'.format(evaluasi[1]*100))
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2620 - accuracy: 0.9101
# test sccuracy =91.01%

# %%
classifier.save('model_cnn_fashion.hds', include_optimizer=True)
print('model sudah disimpan')
# Out:
# INFO:tensorflow:Assets written to: model_cnn_fashion.hds/assets
# model sudah disimpan

# %%
"""
jika ingin menload data 

from keras models import load model
classifier = load_model('model_cnn_fashion.hds')
"""
# Out:
# "\njika ingin menload data \n\nfrom keras models import load model\nclassifier = load_model('model_cnn_fashion.hds')\n"

# %%
hasil_prediksi = classifier.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
fig, axes =plt.subplots(5,5)
axes = axes.ravel()
for i in np.arange(0,5*5):
  axes[i].imshow(X_test[i]. reshape(28,28), cmap = 'gray')
  axes[i].set_title('hasil prediksi = {}\n label asli ={}\n '.format(hasil_prediksi, y_test))
  axes[i].axis('off')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
cm = confusion_matrix(y_test, hasil_prediksi)
cm_label = pd.DataFrame(cm, columns = np.unique(y_test), index = np.unique(y_test))
cm_label.index.name = 'asli'
cm_label.columns.name = 'prediksi'
plt.figure(figsize=(14,10))
sns.heatmap(cm_label, annot=True)

# %%
from sklearn.metrics import classification_report
jumlah_kategori = 10
nama_target = ['kategori {}' .format(i) for i in range(jumlah_kategori)]
print(classification_report(y_test, hasil_prediksi, target_names=nama_target))
# Out:
#               precision    recall  f1-score   support
#
#   kategori 0       0.90      0.84      0.87      1000
#   kategori 1       0.99      0.98      0.99      1000
#   kategori 2       0.85      0.86      0.86      1000
#   kategori 3       0.90      0.93      0.91      1000
#   kategori 4       0.84      0.89      0.86      1000
#   kategori 5       0.98      0.98      0.98      1000
#   kategori 6       0.76      0.74      0.75      1000
#   kategori 7       0.92      0.98      0.95      1000
#   kategori 8       0.97      0.98      0.97      1000
#   kategori 9       0.99      0.93      0.96      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000
